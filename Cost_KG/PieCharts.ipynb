# %% [markdown]
# MITRE Alex Luttman - Spacecraft_summary_data_Jan2010_Jun2021 (4).xlsx

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime

# %%
df = pd.read_excel('Untitled spreadsheet.xlsx')

# %%
df.columns
# Out:
# Index(['Launch Code', 'Launch Year', 'Launch Date', 'Launch time (EST)',
#        'Launch ID/Designation', 'FAA Licensed Launch',
#        'Internationally Competed Launch', 'Launch Type', 'Launch Outcome',
#        'Mission Outcome', 'Vehicle Name', 'Vehicle Mass Class (capacity)',
#        'Launch Organizations', 'Launch Organization Country', 'Launch Site',
#        'Launch Site Country', 'Launch Site Latitude', 'Launch Site Longitude',
#        'Spacecraft Name(s)', 'Launch Date - First Planned or Scheduled'],
#       dtype='object')

# %%
df['Launch Year']
# Out:
# 0      2020
# 1      2020
# 2      2020
# 3      2020
# 4      2020
#        ...
# 995    2010
# 996    2010
# 997    2010
# 998    2010
# 999    2010
# Name: Launch Year, Length: 1000, dtype: int64

# %%
df_2010 = df[df['Launch Year'] == 2010]
df_2021 = df[df['Launch Year'] == 2021]

# %%
# Filter the data for the year 2010
df_2010 = df[df['Launch Year'].dt.year >= 1/1/2010 and df['Launch Year'].dt.year < 1/1/2011]

# %%
df_2010
# Out:
#          Launch Code  Launch Year Launch Date Launch time (EST)  \
# 926  2010-12-29-7328         2010  2010-12-29         4:27 p.m.
# 927  2010-12-26-7339         2010  2010-12-26         4:51 p.m.
# 928  2010-12-25-7900         2010  2010-12-25         5:34 a.m.
# 929  2010-12-17-7890         2010  2010-12-17         3:20 p.m.
# 930  2010-12-15-7323         2010  2010-12-15         2:09 p.m.
# ..               ...          ...         ...               ...
# 995   2010-2-11-7268         2010  2010-02-11         7:39 p.m.
# 996    2010-2-8-7266         2010  2010-02-08         4:14 a.m.
# 997    2010-2-2-7265         2010  2010-02-02        10:45 p.m.
# 998   2010-1-27-7264         2010  2010-01-27         7:18 p.m.
# 999   2010-1-16-7263         2010  2010-01-16        11:12 a.m.
#
#     Launch ID/Designation FAA Licensed Launch Internationally Competed Launch  \
# 926                   NaN                  no                             yes
# ...

# %%
\
# Out:
#          Launch Code  Launch Year Launch Date Launch time (EST)  \
# 926  2010-12-29-7328         2010  2010-12-29         4:27 p.m.
# 927  2010-12-26-7339         2010  2010-12-26         4:51 p.m.
# 928  2010-12-25-7900         2010  2010-12-25         5:34 a.m.
# 929  2010-12-17-7890         2010  2010-12-17         3:20 p.m.
# 930  2010-12-15-7323         2010  2010-12-15         2:09 p.m.
# ..               ...          ...         ...               ...
# 995   2010-2-11-7268         2010  2010-02-11         7:39 p.m.
# 996    2010-2-8-7266         2010  2010-02-08         4:14 a.m.
# 997    2010-2-2-7265         2010  2010-02-02        10:45 p.m.
# 998   2010-1-27-7264         2010  2010-01-27         7:18 p.m.
# 999   2010-1-16-7263         2010  2010-01-16        11:12 a.m.
#
#     Launch ID/Designation FAA Licensed Launch Internationally Competed Launch  \
# 926                   NaN                  no                             yes
# ...

# %%
df_2010_vc = df_2010['Launch Organizations'].value_counts()

# %%
df_2010_vc
# Out:
# China Aerospace Science and Technology Corporation (CASC)    15
# International Launch Services (Russia)                       12
# Russian Ministry of Defense                                  11
# United Launch Alliance                                        7
# Arianespace                                                   6
# Roscosmos (Russian Space Agency)                              4
# Indian Space Research Organisation (ISRO)                     3
# ISC Kosmotras                                                 3
# National Aeronautics and Space Administration (NASA)          3
# Space Exploration Technologies (SpaceX)                       2
# Orbital Sciences Corporation                                  2
# MHI Launch Services                                           2
# The Boeing Company                                            1
# Israel Defense Force (IDF)                                    1
# Korea Aerospace Research Institute (KARI)                     1
# ...

# %%
df_2010_1
# Out:
# China Aerospace Science and Technology Corporation (CASC)    15
# International Launch Services (Russia)                       12
# Russian Ministry of Defense                                  11
# United Launch Alliance                                        7
# Arianespace                                                   6
# Roscosmos (Russian Space Agency)                              4
# Indian Space Research Organisation (ISRO)                     3
# ISC Kosmotras                                                 3
# National Aeronautics and Space Administration (NASA)          3
# Space Exploration Technologies (SpaceX)                       2
# Orbital Sciences Corporation                                  2
# MHI Launch Services                                           2
# The Boeing Company                                            1
# Israel Defense Force (IDF)                                    1
# Korea Aerospace Research Institute (KARI)                     1
# ...

# %%
import matplotlib.cm as cm
# Specify the colormap
cmap_name = 'tab20'  # Replace with your preferred colormap name

# Get the colormap object
cmap = cm.get_cmap(cmap_name)


# Generate a list of colors
colors = cmap.colors

# %%
fig, ax = plt.subplots(figsize=(14, 14), subplot_kw=dict(aspect="equal"))

data = df_2010_vc.values.tolist()
labels = df_2010_vc.index.tolist()
cmap = plt.cm.Paired
#colors = cmap(np.linspace(0, 1, len(data)))
wedges, texts = ax.pie(data, colors = colors)

bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.72)
kw = dict(arrowprops=dict(arrowstyle="-"),
          bbox=bbox_props, zorder=0, va="center")

for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1) / 2. + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = f"angle,angleA=0,angleB={ang}"
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    ax.annotate(labels[i], xy=(x, y), xytext=(1.4 * np.sign(x), 1.2 * y),
                horizontalalignment=horizontalalignment, **kw)

ax.set_title("Matplotlib bakery: A donut")

plt.show()

# %%
fig, ax = plt.subplots(figsize=(14, 14), subplot_kw=dict(aspect="equal"))

data = df_2010_vc.values.tolist()
labels = df_2010_vc.index.tolist()
cmap = plt.cm.Paired
#colors = cmap(np.linspace(0, 1, len(data)))
wedges, texts = ax.pie(data, colors = colors)

bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.72)
kw = dict(arrowprops=dict(arrowstyle="-"),
          bbox=bbox_props, zorder=0, va="center")

for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1) / 2. + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = f"angle,angleA=0,angleB={ang}"
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    ax.annotate(labels[i], xy=(x, y), xytext=(1.4 * np.sign(x), 1.2 * y),
                horizontalalignment=horizontalalignment, **kw)

ax.set_title("Matplotlib bakery: A donut")

plt.show()
